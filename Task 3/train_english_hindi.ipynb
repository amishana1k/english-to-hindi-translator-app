# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
import pickle

# Load dataset
data = pd.read_csv("english_hindi.csv")

# Tokenize English and Hindi words
english_tokenizer = Tokenizer(char_level=False)  # Word-level tokenizer
hindi_tokenizer = Tokenizer(char_level=False)

english_tokenizer.fit_on_texts(data['English'])
hindi_tokenizer.fit_on_texts(data['Hindi'])

# Convert text to sequences
english_sequences = english_tokenizer.texts_to_sequences(data['English'])
hindi_sequences = hindi_tokenizer.texts_to_sequences(data['Hindi'])

# Pad sequences
english_padded = pad_sequences(english_sequences, padding='post')
hindi_padded = pad_sequences(hindi_sequences, padding='post')

# Convert Hindi sequences to class indices
y_data = hindi_padded.argmax(axis=-1)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(english_padded, y_data, test_size=0.2, random_state=42)

# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=len(english_tokenizer.word_index) + 1, output_dim=16, input_length=english_padded.shape[1]),
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(len(hindi_tokenizer.word_index) + 1, activation='softmax')  # Output matches Hindi vocabulary size
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))

# Save the trained model
model.save("english_to_hindi_model.h5")

# Save the tokenizers
with open('english_tokenizer.pkl', 'wb') as f:
    pickle.dump(english_tokenizer, f)

with open('hindi_tokenizer.pkl', 'wb') as f:
    pickle.dump(hindi_tokenizer, f)
# Out:
# Epoch 1/50
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 1.9458 - val_accuracy: 1.0000 - val_loss: 1.9370
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 1.9369 - val_accuracy: 1.0000 - val_loss: 1.9274
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 1.9272 - val_accuracy: 1.0000 - val_loss: 1.9171
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 1.9167 - val_accuracy: 1.0000 - val_loss: 1.9061
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 1.9055 - val_accuracy: 1.0000 - val_loss: 1.8946
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 1.0000 - loss: 1.8938 - val_accuracy: 1.0000 - val_loss: 1.8826
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 1.0000 - loss: 1.8814 - val_accuracy: 1.0000 - val_loss: 1.8698
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 1.0000 - loss: 1.8683 - val_accuracy: 1.0000 - val_loss: 1.8565
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 1.8545 - val_accuracy: 1.0000 - val_loss: 1.8424
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 1.0000 - loss: 1.8400 - val_accuracy: 1.0000 - val_loss: 1.8275
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 1.0000 - loss: 1.8246 - val_accuracy: 1.0000 - val_loss: 1.8118
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 1.8082 - val_accuracy: 1.0000 - val_loss: 1.7953
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 1.7909 - val_accuracy: 1.0000 - val_loss: 1.7778
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 1.0000 - loss: 1.7726 - val_accuracy: 1.0000 - val_loss: 1.7594
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 1.7532 - val_accuracy: 1.0000 - val_loss: 1.7399
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 1.7324 - val_accuracy: 1.0000 - val_loss: 1.7193
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 1.7104 - val_accuracy: 1.0000 - val_loss: 1.6976
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 1.6870 - val_accuracy: 1.0000 - val_loss: 1.6746
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 1.6620 - val_accuracy: 1.0000 - val_loss: 1.6503
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 1.0000 - loss: 1.6354 - val_accuracy: 1.0000 - val_loss: 1.6247
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 1.6071 - val_accuracy: 1.0000 - val_loss: 1.5976
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 1.5768 - val_accuracy: 1.0000 - val_loss: 1.5689
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 1.5445 - val_accuracy: 1.0000 - val_loss: 1.5386
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 1.5101 - val_accuracy: 1.0000 - val_loss: 1.5066
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 1.4733 - val_accuracy: 1.0000 - val_loss: 1.4729
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 1.4340 - val_accuracy: 1.0000 - val_loss: 1.4373
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 1.0000 - loss: 1.3922 - val_accuracy: 1.0000 - val_loss: 1.3999
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 1.3476 - val_accuracy: 1.0000 - val_loss: 1.3604
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 1.3001 - val_accuracy: 1.0000 - val_loss: 1.3190
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 1.2497 - val_accuracy: 1.0000 - val_loss: 1.2756
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 1.1962 - val_accuracy: 1.0000 - val_loss: 1.2301
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 1.0000 - loss: 1.1397 - val_accuracy: 1.0000 - val_loss: 1.1826
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 1.0800 - val_accuracy: 1.0000 - val_loss: 1.1331
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 1.0173 - val_accuracy: 1.0000 - val_loss: 1.0818
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.9518 - val_accuracy: 1.0000 - val_loss: 1.0286
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.8836 - val_accuracy: 1.0000 - val_loss: 0.9738
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.8133 - val_accuracy: 1.0000 - val_loss: 0.9177
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.7413 - val_accuracy: 1.0000 - val_loss: 0.8604
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.6682 - val_accuracy: 1.0000 - val_loss: 0.8024
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 1.0000 - loss: 0.5951 - val_accuracy: 1.0000 - val_loss: 0.7441
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.5229 - val_accuracy: 1.0000 - val_loss: 0.6859
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.4527 - val_accuracy: 1.0000 - val_loss: 0.6285
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.3858 - val_accuracy: 1.0000 - val_loss: 0.5724
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 1.0000 - loss: 0.3233 - val_accuracy: 1.0000 - val_loss: 0.5182
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.2662 - val_accuracy: 1.0000 - val_loss: 0.4666
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.2155 - val_accuracy: 1.0000 - val_loss: 0.4181
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.1716 - val_accuracy: 1.0000 - val_loss: 0.3730
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 1.0000 - loss: 0.1345 - val_accuracy: 1.0000 - val_loss: 0.3318
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 1.0000 - loss: 0.1040 - val_accuracy: 1.0000 - val_loss: 0.2946
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 1.0000 - loss: 0.0795 - val_accuracy: 1.0000 - val_loss: 0.2614
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
